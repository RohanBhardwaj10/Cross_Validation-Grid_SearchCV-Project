# %%
import pandas as pd 
import matplotlib as plt
import numpy as np

# %%
df = pd.read_csv('Advertising.csv')

# %%
x=df.drop('sales',axis=1)
y=df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_other,y_train,y_other = train_test_split(x,y,test_size=0.3,random_state=101)

# %%
x_eval,x_test,y_eval,y_test = train_test_split(x,y,test_size=0.5,random_state=101)
                                              # Remaining 30% is split into evaluatio)n and test sets
# Each is 15% of the original data size

# %%
from sklearn.linear_model import Ridge

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_eval=scaler.transform(x_eval)
x_test=scaler.transform(x_test)
# Out:
# C:\Users\bhard\anaconda3\envs\Proj_new\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# C:\Users\bhard\anaconda3\envs\Proj_new\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
model = Ridge(alpha=100)
model.fit(x_train,y_train)
# Out:
# Ridge(alpha=100)

# %%
y_eval_pred = model.predict(x_eval)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_eval,y_eval_pred)
# Out:
# 183678.99221445902

# %%
model = Ridge(alpha=1)

# %%
model.fit(x_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_eval_pred = model.predict(x_eval)

# %%
mean_squared_error(y_eval,y_eval_pred)
# Out:
# 500715.7295355477

# %%
y_final_test_pred = model.predict(x_test)

# %%
mean_squared_error(y_test,y_final_test_pred)
# Out:
# 459190.6723676635
